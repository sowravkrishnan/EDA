# %% [markdown]
# # <span style='font-family:"Times New Roman"; font-size:16pt;'> <div style="text-align: center"> <h1> Exploratory Data Analysis of Employee Data </h1>

# %% [markdown]
# # <p style="text-align: center;">Data Pre-Processing</p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
df=pd.read_csv('project.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Data Story
# The data frame consists of 458 rows and 9 columns. The table consist of employee details from various teams. From initial analyisis it is observed that Height column has incorrect values.

# %%
df['Height'] = np.random.randint(150, 180,size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     162     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     178     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     166     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     172     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     174     203
# 454      Raul Neto       Utah Jazz      25       PG   24     165     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     166     256
# 456    Jeff Withey       Utah Jazz      24        C   26     175     231
# 457       Priyanka       Utah Jazz      34        C   25     159     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Data Story
#
# We are filling the height column with random integers within the range 150 and 180.

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     164     235
# 2   John Holland  Boston Celtics      30       SG   27     165     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     156     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     170     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ### Data Story
# We have extracted the top 5 values in the data frame.

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     153     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     156     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26     159     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     153     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25     172     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %% [markdown]
# ### Data Story
# We have extracted the bottom 5 values  in data frame.

# %%
des=df.describe(include='all')
des
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# ### Data Story
# We use describe function to extract statistical information about the data frame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %% [markdown]
# ### Data Story
# We use info function to get concise summary of the data frame.

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ### Data Story
# We have observed there are null values in the column College and Salary.

# %%
Q1 = des['Salary'].loc['25%']
Q3 = des['Salary'].loc['75%']
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = (df['Salary'] < lower_bound) | (df['Salary'] > upper_bound)

print(df[outliers][['Name', 'Team', 'Position', 'Salary']])
# Out:
#                   Name                   Team Position      Salary
# 23         Brook Lopez          Brooklyn Nets        C  19689000.0
# 33     Carmelo Anthony        New York Knicks       SF  22875000.0
# 89       Klay Thompson  Golden State Warriors       SG  15501000.0
# 96       Blake Griffin   Los Angeles Clippers       PF  18907726.0
# 98      DeAndre Jordan   Los Angeles Clippers        C  19689000.0
# 100         Chris Paul   Los Angeles Clippers       PG  21468695.0
# 109        Kobe Bryant     Los Angeles Lakers       SF  25000000.0
# 111        Roy Hibbert     Los Angeles Lakers        C  15592217.0
# 143   DeMarcus Cousins       Sacramento Kings        C  15851950.0
# 153       Jimmy Butler          Chicago Bulls       SG  16407500.0
# 164       Derrick Rose          Chicago Bulls       PG  20093064.0
# 168       Kyrie Irving    Cleveland Cavaliers       PG  16407501.0
# 169       LeBron James    Cleveland Cavaliers       SF  22970500.0
# ...

# %% [markdown]
# ### Data Story
# We need to identify if there are any outliers in the Salary column to determine which method we need to use to fill null values. Here we use IQR method,where we find IQR(Inter quartile range). If the values are outside this range then they are outliers.We have all the outliers listed.

# %%
df['College'].fillna('Unknown',inplace=True)
df_sorted = df.sort_values(by='Salary')
df['Salary'].fillna(df_sorted['Salary'].median(),inplace=True)
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College      0
# Salary       0
# Age_Range    0
# dtype: int64

# %% [markdown]
# ### Data Story
# As we found there are outliers, we have used median of the salary values and filled the null values with median. We filled the null values in college column with unknown. Then we used is null function to verify that there is no other null values.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Story
# There are no duplicate rows in the data frame

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# ### Data Frame
# Prints the names of columns in the data frame.

# %%
df.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %% [markdown]
# ### Data Story
# Prints the unique values in column Team  in the data frame.

# %%
df.Team.nunique()
# Out:
# 30

# %% [markdown]
# ### Data Story
# Counts the unique values of Teams present.

# %%
df.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %% [markdown]
# ### Data Story
# Prints the unique values in column Position of the data frame.

# %%
df.Position.nunique()
# Out:
# 5

# %% [markdown]
# ### Data Story
# Counts the number of unique values in column Position.

# %%
df.College.unique()
# Out:
# array(['Texas', 'Marquette', 'Boston University', 'Georgia State',
#        'Unknown', 'LSU', 'Gonzaga', 'Louisville', 'Oklahoma State',
#        'Ohio State', 'Washington', 'Kentucky', 'North Carolina',
#        'Arizona', 'Georgia Tech', 'Cincinnati', 'Miami (FL)', 'Stanford',
#        'Syracuse', 'Saint Louis', 'Kansas', 'Georgetown', 'Texas A&M',
#        'UCLA', 'UNLV', 'Wichita State', "Saint Joseph's", 'Notre Dame',
#        'Norfolk State', 'Duke', 'Murray State', 'Tennessee State',
#        'Bowling Green', 'Purdue', 'Wake Forest', 'Michigan', 'Missouri',
#        'USC', 'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson',
#        'Vanderbilt', 'Michigan State', 'Florida', 'Washington State',
#        'Arizona State', 'Oklahoma', 'Wyoming', "St. John's", 'Maryland',
#        'Wisconsin', 'Utah Valley', 'North Carolina State',
#        'UC Santa Barbara', 'Baylor', 'Connecticut', 'Oregon State',
#        'New Mexico', 'Oregon', 'Creighton', 'Arkansas', 'Memphis',
# ...

# %% [markdown]
# ### Data Story
# Prints the unique values in  the column College.

# %%
df.College.nunique()
# Out:
# 119

# %% [markdown]
# ### Data Story
# Counts the unique values in the column College.

# %%
df.Age.unique()
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40], dtype=int64)

# %% [markdown]
# ### Data Story
# Prints the unique values in the column Age.

# %% [markdown]
# # <p style="text-align: center;">Data Visualisation</p>

# %%
Countdf=pd.DataFrame({"No_of_Employees":df.Team.value_counts()}).reset_index()
Countdf.columns = ['Team','No_of_Employees']
Countdf['Abbreviation'] = Countdf['Team'].apply(lambda x: ''.join(word[0] for word in x.split()))
Countdf = Countdf[['Team', 'Abbreviation', 'No_of_Employees']]
Countdf
# Out:
#                       Team Abbreviation  No_of_Employees
# 0     New Orleans Pelicans          NOP               19
# 1        Memphis Grizzlies           MG               18
# 2                Utah Jazz           UJ               16
# 3          New York Knicks          NYK               16
# 4          Milwaukee Bucks           MB               16
# 5            Brooklyn Nets           BN               15
# 6   Portland Trail Blazers          PTB               15
# 7    Oklahoma City Thunder          OCT               15
# 8           Denver Nuggets           DN               15
# 9       Washington Wizards           WW               15
# 10              Miami Heat           MH               15
# 11       Charlotte Hornets           CH               15
# 12           Atlanta Hawks           AH               15
# 13       San Antonio Spurs          SAS               15
# 14         Houston Rockets           HR               15
# ...

# %% [markdown]
# ### Data Story
# We have created a dataframe Countdf which has details of Number of employees in each team. We added another column called abbreviation and printed the short form for each team.

# %%
plt.figure(figsize=(15, 10))
plt.bar(Countdf['Abbreviation'],Countdf['No_of_Employees'],color=plt.cm.tab20c.colors)
plt.title('Number of Employees in Each Team')
plt.xlabel('No of Employees')
plt.ylabel('Team')
plt.show()

# %% [markdown]
# ### Data Story
# We plotted a bar plot of No of Employees in each team.

# %%
Countdf['Percentage']= (Countdf['No_of_Employees'] / Countdf['No_of_Employees'].sum()) * 100
Countdf
# Out:
#                       Team Abbreviation  No_of_Employees  Percentage
# 0     New Orleans Pelicans          NOP               19    4.148472
# 1        Memphis Grizzlies           MG               18    3.930131
# 2                Utah Jazz           UJ               16    3.493450
# 3          New York Knicks          NYK               16    3.493450
# 4          Milwaukee Bucks           MB               16    3.493450
# 5            Brooklyn Nets           BN               15    3.275109
# 6   Portland Trail Blazers          PTB               15    3.275109
# 7    Oklahoma City Thunder          OCT               15    3.275109
# 8           Denver Nuggets           DN               15    3.275109
# 9       Washington Wizards           WW               15    3.275109
# 10              Miami Heat           MH               15    3.275109
# 11       Charlotte Hornets           CH               15    3.275109
# 12           Atlanta Hawks           AH               15    3.275109
# ...

# %% [markdown]
# ### Data Story
# We have added another column Percentage to show the percentage contribution of each team w.r.t total number of employees.

# %%
plt.pie(Countdf['Percentage'],labels=Countdf['Abbreviation'],colors=plt.cm.tab20c.colors)
plt.title('Percentage of Employees in Each Team')

plt.show()

# %% [markdown]
# ### Data Story
# Shows the Pie Chart of Percentage of employees in each team.

# %%
Positiondf=pd.DataFrame({"No_of_Employees":df.Position.value_counts()}).reset_index()
Positiondf.columns = ['Position','No_of_Employees']
Positiondf
# Out:
#   Position  No_of_Employees
# 0       SG              102
# 1       PF              100
# 2       PG               92
# 3       SF               85
# 4        C               79

# %% [markdown]
# ### Data Story
# We have created a data frame which has the details of number of employees in each position.

# %%
plt.bar(Positiondf['Position'],Positiondf['No_of_Employees'],color=plt.cm.tab20c.colors)
plt.title('Number of Employees in Each Position')
plt.xlabel('Position')
plt.ylabel('No of Employees')
plt.show()

# %% [markdown]
# ### Data Story
# Shows the bar plot of number of employees in each position.

# %%
Agedf=pd.DataFrame({"No":df.Age.value_counts()}).reset_index()
Agedf.columns = ['Age','No_of_Employees']
Agedf
# Out:
#     Age  No_of_Employees
# 0    24               47
# 1    25               46
# 2    27               41
# 3    23               41
# 4    26               36
# 5    28               31
# 6    30               31
# 7    29               28
# 8    22               26
# 9    31               22
# 10   20               19
# 11   21               19
# 12   33               14
# 13   32               13
# 14   34               10
# 15   36               10
# 16   35                9
# 17   37                4
# 18   38                4
# 19   40                3
# 20   39                2
# 21   19                2

# %% [markdown]
# ### Data Story
# We have created a data frame with the details of how many employees are there in each age.

# %%
plt.hist(df['Age'], bins = [15,20,25,30,35,40,45]) 
plt.xlabel('Age')
plt.ylabel('No of Employees')
plt.title('Number of Employees in Each Age Group')

plt.show()

# %% [markdown]
# ### Data Story
# Shows the histogram plot of Number of employees in each age group.

# %%
bins = [14, 19, 24, 29, 34, 39, 44]

df['Age_Range'] = pd.cut(df['Age'], bins)

bin_counts = df['Age_Range'].value_counts().sort_index()
Age_Rangedf=pd.DataFrame({"No_of_Employees":bin_counts}).reset_index()
Age_Rangedf.columns = ['Age_Range','No_of_Employees']
Age_Rangedf
# Out:
#   Age_Range  No_of_Employees
# 0  (14, 19]                2
# 1  (19, 24]              152
# 2  (24, 29]              182
# 3  (29, 34]               90
# 4  (34, 39]               29
# 5  (39, 44]                3

# %% [markdown]
# ### Data Story
# Created a data frame to show how many employees belong to different age group. For Example- (14,19] contains the number of peoples with ages 15,16,17,18,19.

# %%
grouped_df = df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
sorted_df = grouped_df.sort_values(by='Salary', ascending=False)
sorted_df['Abbreviation'] = sorted_df['Team'].apply(lambda x: ''.join(word[0] for word in x.split()))
sorted_df = sorted_df[['Team', 'Abbreviation', 'Position','Salary']]
sorted_df
# Out:
#                    Team Abbreviation Position      Salary
# 67   Los Angeles Lakers          LAL       SF  31866445.0
# 75           Miami Heat           MH       PF  31538671.0
# 53      Houston Rockets           HR       SG  28122883.0
# 116        Phoenix Suns           PS       PG  28002998.0
# 37       Denver Nuggets           DN       SF  27982771.0
# ..                  ...          ...      ...         ...
# 38       Denver Nuggets           DN       SG   2790245.0
# 112  Philadelphia 76ers           P7       SF   1845059.0
# 125    Sacramento Kings           SK       PF   1370152.0
# 74           Miami Heat           MH        C    981348.0
# 107       Orlando Magic           OM       SF    845059.0
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Data Story
# We have created a data frame grouping Team and Position and then gathered how much a team spend for each posion as salary

# %%
plt.figure(figsize=(20, 30))
plt.barh(y=sorted_df['Abbreviation'] + ' - ' + sorted_df['Position'],width=sorted_df['Salary'], color=plt.cm.tab20c.colors)
plt.xlabel('Salary')
plt.ylabel('Team-Position')
plt.title('Team-Position vs Salary Graph')
plt.show()

# %% [markdown]
# ### Data Story
# Bar plot of Team-Position vs Salary

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.show()

# %% [markdown]
# ### Data Story
# A Scatter plot that depicts Relationship between age and salary

# %%
df2=df[['Position','Age','Height','Weight','Salary']]
df2
# Out:
#     Position  Age  Height  Weight     Salary
# 0         PG   25     162     180  7730337.0
# 1         SF   25     178     235  6796117.0
# 2         SG   27     178     205        NaN
# 3         SG   22     166     185  1148640.0
# 4         PF   29     172     231  5000000.0
# ..       ...  ...     ...     ...        ...
# 453       PG   26     174     203  2433333.0
# 454       PG   24     165     179   900000.0
# 455        C   26     166     256  2900000.0
# 456        C   26     175     231   947276.0
# 457        C   25     159     231   947276.0
#
# [458 rows x 5 columns]

# %% [markdown]
# ### Data Story
# Extracted Position, Age, Height, Weight, Salary to form another dataframe.

# %%
df3=df2.drop('Position', axis='columns')
corr = df3.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ### Data Story
# A correlation matrix between Age, Height, Weight, Salary.

# %%
sns.pairplot(df2,hue="Position")
plt.show()

# %% [markdown]
# ### Data Story
# Shows the Pair Plot of Different Variables

# %% [markdown]
# # <span style='font-family:"Times New Roman"; font-size:16pt;'> <div style="text-align: center"> <h1> Inference </h1>

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# * From the initial analysis we observed the Height column had incorrect values so we filled those values with random values within the range of 150 and 180.
#
# * We used head(), tail(), describe(), info() etc functions to get and idea of the values of the table. We got to know about the null values and non-null values of the table and the type of data in each column.
#
# * We found out the outliers in the column Salary using IQR method. As the outliers are observed we used the median() to fill the null values in the column since median is less sensitive to outliers.

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# * From the Number of Employees in each team plot we could identify that the team New Orleans Pelicans has the most number of players which is 19. Memphis Grizzlies holds the second position with 18 players. Majority of the teams has 15 players. Orlando Magic and Minnesota Timberwolves	has 14 players which is the least. [ln 152]
#
# * Additionally from the Percentage of Employees Pie Chart we can infer that New Orleans Pelicans has the highest percentage contribution when it comes to number of employees [ln 15]
#
# * From Number of Employees in Each Position plot we can identify that SG postion has the most number of players with 102 counts and the C position has the least with 79. [ln 21]
#
# * From Number of Employees In Each Age Group Histogram it is evident that the age group 25-30 (25,26,27,28,29) has the most number of employees with 152 counts and the age group 15-20 (15,16,17,18,19) has the least with 2 counts [ln 151]
#
# * From the Team-Postion vs Salary Plot where we grouped Team and Position and plotted it against salary we could conclude that the person in the team Los Angeles Lakers in SF position earns more salary than anyone which is Kobe Byrant. [ln 113]
#
# * Scatter plot helps to find if there is any relationship between 2 variables. In this case we plotted a Age vs Salary curve in which we didn't observe any linear relationship. We could observe that most of the employees falls under 10000000. People earning above 10000000 mostly falls under the age group 24-35. [ln 117]
#
# * A correlation matrix and heat map is plotted and all the values are close to 0 which implies all the variables has almost no correlation with each other.[ln 123]
#
# * Additionally a Pair plot is plotted so that we can plot with multiple combinations of variables. Here we have considered Age, Salary, Height, Weight and plotted different postions. We couldn't identify specific relationship between the variables.[ln 126]
